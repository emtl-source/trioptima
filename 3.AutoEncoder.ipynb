# %% [markdown]
# Defining the autoencoder module

# %%
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
from tensorflow.keras import backend as K

 #r'C:\Users\gusta\Documents\KTH\TriOptima\trioptima/'
#'/Users/elliotlindestam/Documents/Skola/Indek icloud/trioptima/'
your_path = r'C:\Users\gusta\Documents\KTH\TriOptima\trioptima/'
file_name = "RT.IRS_Data_2023_Cleaned_Scaled"

# Load preprocessed data
file_path = your_path + '3.Scaled/' + file_name +'.csv'
data_preprocessed = pd.read_csv(file_path, header=0)

# Convert data to float32
data_preprocessed = data_preprocessed.astype(np.float32)

# Check for inf or NaN values in data
print("Inf values in data: ", np.isinf(data_preprocessed).values.sum())
print("NaN values in data: ", np.isnan(data_preprocessed).values.sum())

# Check to make sure the data is in expected format
try:
    data_preprocessed = data_preprocessed.astype(float)
except ValueError as e:
    print(f"ValueError: {e}")

# Check to make sure the data is in expected format
assert data_preprocessed.applymap(np.isreal).all().all(), "Non-numeric data found"
assert not data_preprocessed.isnull().any().any(), "NaN values found"

# Dimensions
input_dim = data_preprocessed.shape[1]
encoding_dim = int(input_dim / 2)

# Set layer and neurons options
layer_options = [1, 5, 10, 20, 40]
neuron_options = [50, 100, 200, 500, 1000]

# Variables to store the best model's configurations and weights
best_val_loss = float('inf')  # Set initial value to infinity
best_num_layers = None
best_num_neurons = None
best_weights = None

# Iterate over neuron configurations
for num_neurons in neuron_options:
    # Iterate over layer configurations
    for num_layers in layer_options:
        K.clear_session()

        input_layer = layers.Input(shape=(input_dim,))
        encoder_layer = layers.Dense(num_neurons, activation='relu')(input_layer)
        
        # Add extra layers based on num_layers
        for _ in range(1, num_layers):
            encoder_layer = layers.Dense(num_neurons, activation='relu')(encoder_layer)

        decoder_layer = layers.Dense(input_dim, activation='sigmoid')(encoder_layer)

        temp_autoencoder = models.Model(inputs=input_layer, outputs=decoder_layer)
        temp_autoencoder.compile(optimizer='adam', loss='mean_squared_error')
        
        history = temp_autoencoder.fit(
            data_preprocessed, data_preprocessed,
            epochs=10,  # Adjust this as needed
            batch_size=32,
            shuffle=True,
            validation_split=0.1
        )
        
        final_val_loss = history.history['val_loss'][-1]
        if final_val_loss < best_val_loss:
            best_val_loss = final_val_loss
            best_num_layers = num_layers
            best_num_neurons = num_neurons
            best_weights = temp_autoencoder.get_weights()

# Construct the best model with configurations
K.clear_session()
input_layer = layers.Input(shape=(input_dim,))
encoder_layer = layers.Dense(best_num_neurons, activation='relu')(input_layer)
for _ in range(1, best_num_layers):
    encoder_layer = layers.Dense(best_num_neurons, activation='relu')(encoder_layer)
decoder_layer = layers.Dense(input_dim, activation='sigmoid')(encoder_layer)

autoencoder = models.Model(inputs=input_layer, outputs=decoder_layer)
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# Load the best weights into the best model
autoencoder.set_weights(best_weights)

# Display the number of layers and neurons in the best model
print(f"Best Model Configuration:\nNumber of Layers: {best_num_layers}\nNumber of Neurons per Layer: {best_num_neurons}")
# Out:
# Inf values in data:  0
# NaN values in data:  0
# C:\Users\gusta\AppData\Local\Temp\ipykernel_11068\2109579143.py:30: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   assert data_preprocessed.applymap(np.isreal).all().all(), "Non-numeric data found"
# Epoch 1/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.6895 - val_loss: 16597.6250
# Epoch 2/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6641 - val_loss: 16597.6133
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6504 - val_loss: 16597.6074
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6465 - val_loss: 16597.6074
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6484 - val_loss: 16597.6055
# Epoch 6/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6387 - val_loss: 16597.6035
# Epoch 7/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6387 - val_loss: 16597.6035
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6387 - val_loss: 16597.6016
# Epoch 9/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6426 - val_loss: 16597.6016
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.6387 - val_loss: 16597.6016
# Epoch 1/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.5508 - val_loss: 16597.2832
# Epoch 2/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3555 - val_loss: 16597.2754
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3457 - val_loss: 16597.2695
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3379 - val_loss: 16597.2637
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3301 - val_loss: 16597.2500
# Epoch 6/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3184 - val_loss: 16597.2402
# Epoch 7/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3086 - val_loss: 16597.2383
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3086 - val_loss: 16597.2383
# Epoch 9/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3047 - val_loss: 16597.2305
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.2988 - val_loss: 16597.2285
# Epoch 1/10
# 164/164 [==============================] - 2s 3ms/step - loss: 16582.4277 - val_loss: 16597.2871
# Epoch 2/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16582.3184 - val_loss: 16597.2441
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3145 - val_loss: 16597.2441
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3184 - val_loss: 16597.2441
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 6/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3203 - val_loss: 16597.2383
# Epoch 7/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3066 - val_loss: 16597.2363
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3047 - val_loss: 16597.2344
# Epoch 9/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16582.3027 - val_loss: 16597.2363
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3027 - val_loss: 16597.2344
# Epoch 1/10
# 164/164 [==============================] - 3s 5ms/step - loss: 16582.8496 - val_loss: 16597.2441
# Epoch 2/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 3/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3145 - val_loss: 16597.2441
# Epoch 4/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3184 - val_loss: 16597.2441
# Epoch 5/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 6/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3242 - val_loss: 16597.2441
# Epoch 7/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 8/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3184 - val_loss: 16597.2402
# Epoch 9/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3066 - val_loss: 16597.2383
# Epoch 10/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3086 - val_loss: 16597.2402
# Epoch 1/10
# 164/164 [==============================] - 5s 7ms/step - loss: 16583.0703 - val_loss: 16597.3418
# Epoch 2/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4180 - val_loss: 16597.3418
# Epoch 3/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4121 - val_loss: 16597.3418
# Epoch 4/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4219 - val_loss: 16597.3418
# Epoch 5/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4102 - val_loss: 16597.3418
# Epoch 6/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4180 - val_loss: 16597.3418
# Epoch 7/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4180 - val_loss: 16597.3418
# Epoch 8/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4102 - val_loss: 16597.3418
# Epoch 9/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4141 - val_loss: 16597.3418
# Epoch 10/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.4199 - val_loss: 16597.3418
# Epoch 1/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16599.0215 - val_loss: 16613.9434
# Epoch 2/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9805 - val_loss: 16613.9336
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9609 - val_loss: 16613.9219
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9609 - val_loss: 16613.9199
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9570 - val_loss: 16613.9199
# Epoch 6/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9590 - val_loss: 16613.9199
# Epoch 7/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9531 - val_loss: 16613.9199
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9590 - val_loss: 16613.9199
# Epoch 9/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9531 - val_loss: 16613.9199
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16598.9551 - val_loss: 16613.9199
# Epoch 1/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.5332 - val_loss: 16597.3379
# Epoch 2/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.4023 - val_loss: 16597.3281
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.4023 - val_loss: 16597.3262
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.4004 - val_loss: 16597.3242
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.4062 - val_loss: 16597.3262
# Epoch 6/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16582.4004 - val_loss: 16597.3242
# Epoch 7/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16582.4004 - val_loss: 16597.3262
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.4004 - val_loss: 16597.3223
# Epoch 9/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3926 - val_loss: 16597.3145
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16582.3945 - val_loss: 16597.3145
# Epoch 1/10
# 164/164 [==============================] - 2s 4ms/step - loss: 16582.4531 - val_loss: 16597.2441
# Epoch 2/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 3/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3145 - val_loss: 16597.2441
# Epoch 4/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3203 - val_loss: 16597.2383
# Epoch 5/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3066 - val_loss: 16597.2383
# Epoch 6/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3047 - val_loss: 16597.2383
# Epoch 7/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3047 - val_loss: 16597.2324
# Epoch 8/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3086 - val_loss: 16597.2324
# Epoch 9/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16582.3086 - val_loss: 16597.2363
# Epoch 10/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16582.3086 - val_loss: 16597.2344
# Epoch 1/10
# 164/164 [==============================] - 3s 6ms/step - loss: 16582.6191 - val_loss: 16597.3164
# Epoch 2/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3887 - val_loss: 16597.3164
# Epoch 3/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3906 - val_loss: 16597.3164
# Epoch 4/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3887 - val_loss: 16597.3164
# Epoch 5/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3867 - val_loss: 16597.3164
# Epoch 6/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3926 - val_loss: 16597.3164
# Epoch 7/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3887 - val_loss: 16597.3164
# Epoch 8/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3848 - val_loss: 16597.3164
# Epoch 9/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3945 - val_loss: 16597.3164
# Epoch 10/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16582.3906 - val_loss: 16597.3164
# Epoch 1/10
# 164/164 [==============================] - 6s 8ms/step - loss: 16582.8535 - val_loss: 16597.3516
# Epoch 2/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4316 - val_loss: 16597.3691
# Epoch 3/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4434 - val_loss: 16597.3691
# Epoch 4/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4434 - val_loss: 16597.3691
# Epoch 5/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4453 - val_loss: 16597.3691
# Epoch 6/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4434 - val_loss: 16597.3691
# Epoch 7/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4473 - val_loss: 16597.3691
# Epoch 8/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4434 - val_loss: 16597.3691
# Epoch 9/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4473 - val_loss: 16597.3691
# Epoch 10/10
# 164/164 [==============================] - 1s 6ms/step - loss: 16582.4453 - val_loss: 16597.3691
# Epoch 1/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.9023 - val_loss: 16605.7949
# Epoch 2/10
# 164/164 [==============================] - 0s 3ms/step - loss: 16590.8516 - val_loss: 16605.7754
# Epoch 3/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8398 - val_loss: 16605.7676
# Epoch 4/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8320 - val_loss: 16605.7617
# Epoch 5/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8379 - val_loss: 16605.7617
# Epoch 6/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8281 - val_loss: 16605.7617
# Epoch 7/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8301 - val_loss: 16605.7617
# Epoch 8/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8281 - val_loss: 16605.7617
# Epoch 9/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8379 - val_loss: 16605.7637
# Epoch 10/10
# 164/164 [==============================] - 0s 2ms/step - loss: 16590.8281 - val_loss: 16605.7520
# Epoch 1/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7324 - val_loss: 16605.6777
# Epoch 2/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7070 - val_loss: 16605.6699
# Epoch 3/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7051 - val_loss: 16605.6699
# Epoch 4/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7051 - val_loss: 16605.6699
# Epoch 5/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7090 - val_loss: 16605.6699
# Epoch 6/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7031 - val_loss: 16605.6699
# Epoch 7/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7031 - val_loss: 16605.6699
# Epoch 8/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7051 - val_loss: 16605.6699
# Epoch 9/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7051 - val_loss: 16605.6699
# Epoch 10/10
# 164/164 [==============================] - 1s 3ms/step - loss: 16590.7031 - val_loss: 16605.6699
# Epoch 1/10
# 164/164 [==============================] - 2s 6ms/step - loss: 16582.3965 - val_loss: 16597.2695
# Epoch 2/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3301 - val_loss: 16597.2441
# Epoch 3/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3125 - val_loss: 16597.2441
# Epoch 4/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3223 - val_loss: 16597.2441
# Epoch 5/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3164 - val_loss: 16597.2402
# Epoch 6/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3086 - val_loss: 16597.2383
# Epoch 7/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3125 - val_loss: 16597.2383
# Epoch 8/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3086 - val_loss: 16597.2344
# Epoch 9/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3086 - val_loss: 16597.2344
# Epoch 10/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16582.3086 - val_loss: 16597.2383
# Epoch 1/10
# 164/164 [==============================] - 4s 9ms/step - loss: 16582.4707 - val_loss: 16597.2930
# Epoch 2/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3652 - val_loss: 16597.2930
# Epoch 3/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3672 - val_loss: 16597.2930
# Epoch 4/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3691 - val_loss: 16597.2930
# Epoch 5/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3730 - val_loss: 16597.2930
# Epoch 6/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3672 - val_loss: 16597.2930
# Epoch 7/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3730 - val_loss: 16597.2930
# Epoch 8/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3652 - val_loss: 16597.2930
# Epoch 9/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3711 - val_loss: 16597.2930
# Epoch 10/10
# 164/164 [==============================] - 1s 7ms/step - loss: 16582.3672 - val_loss: 16597.2930
# Epoch 1/10
# 164/164 [==============================] - 7s 15ms/step - loss: 16582.6387 - val_loss: 16597.3848
# Epoch 2/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4590 - val_loss: 16597.3848
# Epoch 3/10
# 164/164 [==============================] - 2s 14ms/step - loss: 16582.4629 - val_loss: 16597.3848
# Epoch 4/10
# 164/164 [==============================] - 2s 14ms/step - loss: 16582.4629 - val_loss: 16597.3848
# Epoch 5/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4609 - val_loss: 16597.3848
# Epoch 6/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4648 - val_loss: 16597.3848
# Epoch 7/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4609 - val_loss: 16597.3848
# Epoch 8/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4629 - val_loss: 16597.3848
# Epoch 9/10
# 164/164 [==============================] - 2s 15ms/step - loss: 16582.4609 - val_loss: 16597.3848
# Epoch 10/10
# 164/164 [==============================] - 2s 13ms/step - loss: 16582.4609 - val_loss: 16597.3848
# Epoch 1/10
# 164/164 [==============================] - 1s 5ms/step - loss: 16590.8555 - val_loss: 16605.7695
# Epoch 2/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7930 - val_loss: 16605.7227
# Epoch 3/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7871 - val_loss: 16605.7188
# Epoch 4/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7832 - val_loss: 16605.7148
# Epoch 5/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7891 - val_loss: 16605.7129
# Epoch 6/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7812 - val_loss: 16605.7070
# Epoch 7/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7754 - val_loss: 16605.7031
# Epoch 8/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7637 - val_loss: 16605.6836
# Epoch 9/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7363 - val_loss: 16605.6641
# Epoch 10/10
# 164/164 [==============================] - 1s 4ms/step - loss: 16590.7305 - val_loss: 16605.6641
# Epoch 1/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.6367 - val_loss: 16597.5469
# Epoch 2/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5879 - val_loss: 16597.5469
# Epoch 3/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5859 - val_loss: 16597.5469
# Epoch 4/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5879 - val_loss: 16597.5469
# Epoch 5/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5859 - val_loss: 16597.5469
# Epoch 6/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5918 - val_loss: 16597.5469
# Epoch 7/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5879 - val_loss: 16597.5469
# Epoch 8/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5918 - val_loss: 16597.5469
# Epoch 9/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5879 - val_loss: 16597.5449
# Epoch 10/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5840 - val_loss: 16597.5469
# Epoch 1/10
# 164/164 [==============================] - 4s 18ms/step - loss: 16582.4863 - val_loss: 16597.3203
# Epoch 2/10
# 164/164 [==============================] - 3s 18ms/step - loss: 16582.3945 - val_loss: 16597.3223
# Epoch 3/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.4004 - val_loss: 16597.3223
# Epoch 4/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.4004 - val_loss: 16597.3223
# Epoch 5/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.3945 - val_loss: 16597.3223
# Epoch 6/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.3984 - val_loss: 16597.3223
# Epoch 7/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.3926 - val_loss: 16597.3223
# Epoch 8/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.3984 - val_loss: 16597.3223
# Epoch 9/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.4004 - val_loss: 16597.3223
# Epoch 10/10
# 164/164 [==============================] - 3s 17ms/step - loss: 16582.3945 - val_loss: 16597.3223
# Epoch 1/10
# 164/164 [==============================] - 7s 32ms/step - loss: 16582.3730 - val_loss: 16597.2441
# Epoch 2/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 3/10
# 164/164 [==============================] - 5s 30ms/step - loss: 16582.3145 - val_loss: 16597.2441
# Epoch 4/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 5/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 6/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 7/10
# 164/164 [==============================] - 5s 30ms/step - loss: 16582.3242 - val_loss: 16597.2441
# Epoch 8/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3164 - val_loss: 16597.2441
# Epoch 9/10
# 164/164 [==============================] - 5s 31ms/step - loss: 16582.3184 - val_loss: 16597.2402
# Epoch 10/10
# 164/164 [==============================] - 5s 32ms/step - loss: 16582.3184 - val_loss: 16597.2383
# Epoch 1/10
# 164/164 [==============================] - 15s 61ms/step - loss: 16582.5566 - val_loss: 16597.3984
# Epoch 2/10
# 164/164 [==============================] - 10s 58ms/step - loss: 16582.4414 - val_loss: 16597.3984
# Epoch 3/10
# 164/164 [==============================] - 10s 58ms/step - loss: 16582.4414 - val_loss: 16597.3984
# Epoch 4/10
# 164/164 [==============================] - 10s 58ms/step - loss: 16582.4414 - val_loss: 16597.3984
# Epoch 5/10
# 164/164 [==============================] - 10s 58ms/step - loss: 16582.4414 - val_loss: 16597.3984
# Epoch 6/10
# 164/164 [==============================] - 10s 58ms/step - loss: 16582.4375 - val_loss: 16597.3984
# Epoch 7/10
# 164/164 [==============================] - 10s 59ms/step - loss: 16582.4453 - val_loss: 16597.3984
# Epoch 8/10
# 164/164 [==============================] - 10s 59ms/step - loss: 16582.4434 - val_loss: 16597.3984
# Epoch 9/10
# 164/164 [==============================] - 9s 58ms/step - loss: 16582.4434 - val_loss: 16597.3984
# Epoch 10/10
# 164/164 [==============================] - 9s 57ms/step - loss: 16582.4395 - val_loss: 16597.3984
# Epoch 1/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.6406 - val_loss: 16597.5391
# Epoch 2/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.6113 - val_loss: 16597.5332
# Epoch 3/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.6016 - val_loss: 16597.5254
# Epoch 4/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.5938 - val_loss: 16597.5215
# Epoch 5/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5898 - val_loss: 16597.5215
# Epoch 6/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.5918 - val_loss: 16597.5215
# Epoch 7/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.5996 - val_loss: 16597.5215
# Epoch 8/10
# 164/164 [==============================] - 2s 10ms/step - loss: 16582.5938 - val_loss: 16597.5215
# Epoch 9/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.5977 - val_loss: 16597.5195
# Epoch 10/10
# 164/164 [==============================] - 2s 11ms/step - loss: 16582.5879 - val_loss: 16597.5137
# Epoch 1/10
# 164/164 [==============================] - 9s 48ms/step - loss: 16582.5820 - val_loss: 16597.4570
# Epoch 2/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5371 - val_loss: 16597.4570
# Epoch 3/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5293 - val_loss: 16597.4570
# Epoch 4/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5312 - val_loss: 16597.4570
# Epoch 5/10
# 164/164 [==============================] - 8s 48ms/step - loss: 16582.5273 - val_loss: 16597.4570
# Epoch 6/10
# 164/164 [==============================] - 8s 50ms/step - loss: 16582.5254 - val_loss: 16597.4570
# Epoch 7/10
# 164/164 [==============================] - 8s 48ms/step - loss: 16582.5273 - val_loss: 16597.4570
# Epoch 8/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5234 - val_loss: 16597.4570
# Epoch 9/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5371 - val_loss: 16597.4570
# Epoch 10/10
# 164/164 [==============================] - 8s 47ms/step - loss: 16582.5273 - val_loss: 16597.4570
# Epoch 1/10
# 164/164 [==============================] - 17s 94ms/step - loss: 16582.5312 - val_loss: 16597.3965
# Epoch 2/10
# 164/164 [==============================] - 16s 95ms/step - loss: 16582.4355 - val_loss: 16597.3965
# Epoch 3/10
# 164/164 [==============================] - 15s 94ms/step - loss: 16582.4395 - val_loss: 16597.3965
# Epoch 4/10
# 164/164 [==============================] - 15s 92ms/step - loss: 16582.4414 - val_loss: 16597.3965
# Epoch 5/10
# 164/164 [==============================] - 15s 92ms/step - loss: 16582.4355 - val_loss: 16597.3965
# Epoch 6/10
# 164/164 [==============================] - 15s 91ms/step - loss: 16582.4375 - val_loss: 16597.3965
# Epoch 7/10
# 164/164 [==============================] - 15s 92ms/step - loss: 16582.4395 - val_loss: 16597.3965
# Epoch 8/10
# 164/164 [==============================] - 15s 92ms/step - loss: 16582.4414 - val_loss: 16597.3965
# Epoch 9/10
# 164/164 [==============================] - 15s 92ms/step - loss: 16582.4395 - val_loss: 16597.3965
# Epoch 10/10
# 164/164 [==============================] - 15s 91ms/step - loss: 16582.4414 - val_loss: 16597.3965
# Epoch 1/10
# 164/164 [==============================] - 31s 178ms/step - loss: 16582.4004 - val_loss: 16597.2715
# Epoch 2/10
# 164/164 [==============================] - 29s 176ms/step - loss: 16582.3457 - val_loss: 16597.2715
# Epoch 3/10
# 164/164 [==============================] - 29s 177ms/step - loss: 16582.3516 - val_loss: 16597.2715
# Epoch 4/10
# 164/164 [==============================] - 29s 176ms/step - loss: 16582.3438 - val_loss: 16597.2715
# Epoch 5/10
# 164/164 [==============================] - 29s 174ms/step - loss: 16582.3418 - val_loss: 16597.2715
# Epoch 6/10
# 164/164 [==============================] - 29s 176ms/step - loss: 16582.3477 - val_loss: 16597.2715
# Epoch 7/10
# 164/164 [==============================] - 29s 175ms/step - loss: 16582.3496 - val_loss: 16597.2715
# Epoch 8/10
# 164/164 [==============================] - 29s 175ms/step - loss: 16582.3457 - val_loss: 16597.2715
# Epoch 9/10
# 164/164 [==============================] - 29s 175ms/step - loss: 16582.3516 - val_loss: 16597.2715
# Epoch 10/10
# 164/164 [==============================] - 29s 177ms/step - loss: 16582.3438 - val_loss: 16597.2715
# Epoch 1/10
# 164/164 [==============================] - 61s 347ms/step - loss: 16582.4922 - val_loss: 16597.3027
# Epoch 2/10
# 164/164 [==============================] - 56s 344ms/step - loss: 16582.3809 - val_loss: 16597.3027
# Epoch 3/10
# 164/164 [==============================] - 56s 342ms/step - loss: 16582.3711 - val_loss: 16597.3027
# Epoch 4/10
# 164/164 [==============================] - 57s 345ms/step - loss: 16582.3730 - val_loss: 16597.3027
# Epoch 5/10
# 164/164 [==============================] - 57s 350ms/step - loss: 16582.3809 - val_loss: 16597.3027
# Epoch 6/10
# 164/164 [==============================] - 57s 346ms/step - loss: 16582.3789 - val_loss: 16597.3027
# Epoch 7/10
# 164/164 [==============================] - 58s 353ms/step - loss: 16582.3750 - val_loss: 16597.3027
# Epoch 8/10
# 164/164 [==============================] - 56s 343ms/step - loss: 16582.3750 - val_loss: 16597.3027
# Epoch 9/10
# 164/164 [==============================] - 57s 346ms/step - loss: 16582.3789 - val_loss: 16597.3027
# Epoch 10/10
# 164/164 [==============================] - 56s 343ms/step - loss: 16582.3750 - val_loss: 16597.3027
# Best Model Configuration:
# Number of Layers: 5
# Number of Neurons per Layer: 50

# %% [markdown]
# Anomaly detection

# %%
# Obtain the reconstructed data
predictions = autoencoder.predict(data_preprocessed)

# Measure the reconstruction error
mse = np.mean(np.power(data_preprocessed - predictions, 2), axis=1)

# Convert mse to a DataFrame for easier handling
mse_df = pd.DataFrame({'reconstruction_error': mse})

# Display basic statistics of the error
print(mse_df.describe())
# Out:
# 182/182 [==============================] - 0s 1ms/step
#        reconstruction_error
# count           5810.000000
# mean           16583.795129
# std              119.083268
# min            16511.014533
# 25%            16530.031563
# 50%            16546.867474
# 75%            16601.172222
# max            21004.876833

# %% [markdown]
# Visualize

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))
sns.histplot(mse_df['reconstruction_error'], bins=50, kde=True)
plt.title('Reconstruction error distribution')
plt.xlabel('Reconstruction error')
plt.ylabel('Frequency')


threshold = np.percentile(mse_df['reconstruction_error'], 99.9)
plt.axvline(x=threshold, color='r', linestyle='--', label=f'Threshold: {threshold:.2f}')
plt.show() 
print(f"Anomaly threshold: {threshold}")
# Out:
# Anomaly threshold: 17245.891053284005

# %% [markdown]
# Test new data for outliers

# %%
import pandas as pd
import numpy as np

# Set the file paths
file_name_test = "RT.IRS_Data_2023_Cleaned"
t_data_path = your_path + '2.Cleaned/' + file_name_test +'.csv' # THIS IS THE ORIGINAL TEST DATA 
t_data_scaled_path = your_path + '3.Scaled/' + file_name_test + '_Scaled.csv' # THIS IS THE SCALED TEST DATA

# Load new trade data from CSV (both processed and original)
t_data_scaled = pd.read_csv(t_data_scaled_path)
t_data = pd.read_csv(t_data_path)

# Convert data to float32
t_data_scaled = t_data_scaled.astype(np.float32)

# Check for inf or NaN values in data
print("Inf values in data: ", np.isinf(t_data_scaled).values.sum())
print("NaN values in data: ", np.isnan(t_data_scaled).values.sum())

# Check to make sure the data is in expected format
try:
    t_data_scaled = t_data_scaled.astype(float)
except ValueError as e:
    print(f"ValueError: {e}")


# Make sure the autoencoder variable is already defined and trained
# Predict with the autoencoder
new_predictions = autoencoder.predict(t_data_scaled)

# Measure the reconstruction error
new_mse = np.mean(np.power(t_data_scaled - new_predictions, 2), axis=1)
new_mse_df = pd.DataFrame({'reconstruction_error': new_mse})

# Determine whether each trade is an outlier or not
outlier_indices = new_mse_df[new_mse_df['reconstruction_error'] > threshold].index

# Filter the outlier trades from the original data using the outlier indices
outlier_trades_original = t_data.iloc[outlier_indices]

# Save the outlier trades to a CSV file in the original format
outlier_file_path = your_path + '4.Outliers/' + 'Outlier_IRS_test_full.csv'
outlier_trades_original.to_csv(outlier_file_path, index=False)
# Out:
# Inf values in data:  0
# NaN values in data:  0
# 182/182 [==============================] - 0s 1ms/step
